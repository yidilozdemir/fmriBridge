# %%
import datalad
import numpy as np
import pandas as pd,
from scipy import signal
import nipype 
import nipype.algorithms.confounds as pca
import nibabel as nib
# Out:
# [WARNING] realpath of PWD=/Users/idil is /Users/idil whenever os.getcwd()=/Users/idil/data_to_language. From now on will be returning os.getcwd(). Directory symlinks in the paths will be resolved

# %%
# !datalad install https://github.com/OpenNeuroDatasets/ds000030.git
# Out:
# Clone attempt:   0%|              | 0.00/2.00 [00:00<?, ? Candidate locations/s]
# Cloning (counting objects):   0%|            | 0.00/9.58k [00:00<?, ? objects/s]
# Cloning (counting objects):   0%|    | 1.00/9.58k [00:00<00:00, 43.7k objects/s]
# Cloning (counting objects):   1%|     | 96.0/9.58k [00:00<00:00, 632k objects/s]
# Cloning (counting objects):   2%|      | 192/9.58k [00:00<00:00, 689k objects/s]
# Cloning (counting objects):   3%|▏     | 288/9.58k [00:00<00:00, 741k objects/s]
# Cloning (counting objects):   4%|▏     | 384/9.58k [00:00<00:00, 761k objects/s]
# Cloning (counting objects):   5%|▎     | 480/9.58k [00:00<00:00, 786k objects/s]
# Cloning (counting objects):   6%|▎     | 575/9.58k [00:00<00:00, 804k objects/s]
# Cloning (counting objects):   7%|▍     | 671/9.58k [00:00<00:00, 820k objects/s]
# Cloning (counting objects):   8%|▍     | 767/9.58k [00:00<00:00, 800k objects/s]
# Cloning (counting objects):   9%|▌     | 863/9.58k [00:00<00:00, 805k objects/s]
# ...

# %%
#mask=nib.load('../{}/masks/{}.nii.gz'.format(subj,m)).get_data()
#data = nib.load('../{}/{}/model/bodyloc.feat/stats/zstat{}.nii.gz'.format(subj,ses,con)).get_data()
#zstat = data[mask > 0].mean()

from sklearn.datasets import load_digits
from sklearn.decomposition import FastICA
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-c73310c3bce2> in <module>
#       3 #zstat = data[mask > 0].mean()
#       4
# ----> 5 from sklearn.datasets import load_digits
#       6 from sklearn.decomposition import FastICA
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
import sklearn

# %%
from sklearn.datasets import load_digits
from sklearn.decomposition import FastICA

# %%
X, _ = load_digits(return_X_y=True)

# %%
transformer = FastICA(n_components=10,random_state=0)

# %%
X_transformed = transformer.fit_transform(X)

# %%
X_transformed[100]
# Out:
# array([-0.04496895, -0.00398438,  0.00911142, -0.00202431,  0.01040029,
#        -0.04887442,  0.00040118, -0.02841722,  0.0200895 ,  0.02742475])
